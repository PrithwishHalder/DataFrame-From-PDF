# %%
import pandas as pd
import tabula as tb

# %%
columns = ["Sr_No","Claims_Experience","For_Death For_Maturity","Survival_Benefit","For_Annuities_Pension","For_Surrender","Other_Benefits","Date"]
df = tb.read_pdf("Q1.pdf",pages = "all", multiple_tables = True,lattice=True )

# %%
# df[0].columns=[1,2]
# date = df[0][2][2]
# date = date.strip("Date:")
# date

# %%
# df[0].drop([0,1,2,3], inplace=True)
# df[0]

# %%
df[1]
# Out:
#                                  PERIODIC DISCLOSURES  \
# 0   FORM L-40 Group claims data for Life till year...
# 1   Insurer: Aditya Birla Sun Life Insurance Co. L...
# 2                                  No. of claims only
# 3                                             Sr. No.
# 4                                                   1
# 5                                                   2
# 6                                                   3
# 7                                                   4
# 8                                                   a
# 9                                                   b
# 10                                                  5
# 11                                                  6
# 12                                                  7
# 13                                                  8
# 14                                                NaN
# 15                                                NaN
# ...
